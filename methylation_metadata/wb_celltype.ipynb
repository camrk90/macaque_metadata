# %%
import pandas as pd
import os

# %%
#Set session paths
location=input("Where are you working today? (Options: 'locally', 'SOL')")

if location=='locally':
    path='/Users/cameronkelsey/Documents/smack_lab/cayo_data/'
elif location=='SOL':
    path='/scratch/ckelsey4/Cayo_meth/'

cell_path=f'{path}wb_cell_counts/cell_populations-freq_of_parent'

# %%
#Import WB celltype data
dirs=[f for f in os.listdir(cell_path) if not f.startswith('.')]

full_paths=[f'{cell_path}/{d}' for d in dirs]

# %%
type(dirs)
